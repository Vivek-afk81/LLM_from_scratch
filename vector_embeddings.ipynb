# %% [markdown]
# <a href="https://colab.research.google.com/github/Vivek-afk81/LLM_from_scratch/blob/main/vector_embeddings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 58.6 MB/s eta 0:00:00
# ...

# %%
import gensim.downloader as api
model=api.load("word2vec-google-news-300") # Download the model and return as object ready to use
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %% [markdown]
# Vectors can capture semantic meaning because words that appear in similar contexts end up with similar vectors.
#
# * dog     → [ 0.21,  1.02, -0.33,  0.87,  0.44 ]
# * cat     → [ 0.19,  0.98, -0.29,  0.90,  0.41 ]
#
# * apple   → [-1.12, -0.45,  0.88, -0.66,  1.09 ]
# * banana  → [-1.05, -0.48,  0.91, -0.62,  1.03 ]
#
# these are 5 dimensional vector space not enough to capture the essence of semantic meaning
#
# we will use :-
# word2vec-google-news-300 is a widely used pre-trained word embedding model that represents words as 300-dimensional vectors.

# %%
word_vectors=model

print(word_vectors['chicken'])
print(word_vectors['banana'].shape)
# Out:
# [-0.13476562 -0.02404785  0.04418945  0.27539062 -0.03271484  0.13183594
#   0.17382812 -0.00095367 -0.0625      0.20996094 -0.03051758 -0.3046875
#  -0.10742188 -0.08203125 -0.43359375  0.03637695 -0.11474609  0.01092529
#  -0.34375    -0.02929688  0.30273438 -0.08203125  0.22265625  0.11083984
#  -0.14257812 -0.04443359 -0.01745605  0.01531982  0.0018692   0.23828125
#  -0.26367188 -0.15136719  0.13183594 -0.12792969  0.0703125   0.24609375
#   0.17871094  0.12353516  0.06396484  0.265625   -0.12158203 -0.22558594
#   0.13867188  0.125      -0.03588867 -0.20019531 -0.08837891 -0.00234985
#   0.20703125  0.21679688 -0.12695312  0.23730469  0.0234375   0.1328125
#  -0.06835938 -0.09179688  0.17089844 -0.07617188  0.22070312  0.03735352
#  -0.04492188  0.20410156 -0.12011719 -0.00543213  0.23632812 -0.28125
#  -0.1484375  -0.07373047  0.21972656 -0.08007812  0.41210938 -0.0625
#   0.03149414 -0.03271484 -0.09912109 -0.25585938 -0.14941406 -0.28710938
# ...

# %% [markdown]
# ###similar words
#
#
# KING+WOMAN-MAN=?

# %%
#example of using most_similar
print(word_vectors.most_similar(positive=['king','woman'],negative=['man'], topn=10))
# Out:
# [('queen', 0.7118193507194519), ('monarch', 0.6189674139022827), ('princess', 0.5902431011199951), ('crown_prince', 0.5499460697174072), ('prince', 0.5377321839332581), ('kings', 0.5236844420433044), ('Queen_Consort', 0.5235945582389832), ('queens', 0.518113374710083), ('sultan', 0.5098593235015869), ('monarchy', 0.5087411403656006)]

# %% [markdown]
# #Checking the similarity between similar pair of words

# %%
# Example of calculating similarity

#gender pairs (high similarity)
print(word_vectors.similarity('actor', 'actress'))
print(word_vectors.similarity('father', 'mother'))
print(word_vectors.similarity('husband', 'wife'))
print(word_vectors.similarity('brother', 'sister'))
print("\n")
#Synonyms (very high similarity)
print(word_vectors.similarity('big', 'large'))
print(word_vectors.similarity('small', 'tiny'))
print(word_vectors.similarity('fast', 'quick'))
print(word_vectors.similarity('happy', 'joyful'))
print("\n")
# Weak or unrelated pairs
print(word_vectors.similarity('paper', 'water'))
print(word_vectors.similarity('banana', 'justice'))
print(word_vectors.similarity('car', 'happiness'))
# Out:
# 0.793001
# 0.79014826
# 0.8294167
# 0.71603835
#
#
# 0.5561479
# 0.7187927
# 0.57016057
# 0.42381963
#
#
# 0.11408084
# 0.04055138
# 0.11088438

# %%
print(word_vectors.most_similar('paper',topn=5))
# Out:
# [('They_unroll_toilet', 0.6297824382781982), ('papers', 0.5981324911117554), ('Accelerating_3G', 0.5678660869598389), ('Paper', 0.5547706484794617), ('cloth_swabs', 0.5477097034454346)]

# %% [markdown]
# ###Vector similarity

# %%
import numpy as np

# Words to compare
word1 = 'man'
word2 = 'woman'

word3 = 'semiconductor'
word4 = 'earthworm'

word5 = 'hi'
word6 = 'hello'

# Calculate the vector differences
vector_difference1 = model[word1] - model[word2]
vector_difference2 = model[word3] - model[word4]
vector_difference3 = model[word5] - model[word6]

# Calculate the magnitudes of the vector differences
magnitude_of_difference1 = np.linalg.norm(vector_difference1)
magnitude_of_difference2 = np.linalg.norm(vector_difference2)
magnitude_of_difference3 = np.linalg.norm(vector_difference3)

# Print results
print("The magnitude of the difference between '{}' and '{}' is {:.2f}".format(word1, word2, magnitude_of_difference1))
print("The magnitude of the difference between '{}' and '{}' is {:.2f}".format(word3, word4, magnitude_of_difference2))
print("The magnitude of the difference between '{}' and '{}' is {:.2f}".format(word5, word6, magnitude_of_difference3))
# Out:
# The magnitude of the difference between 'man' and 'woman' is 1.73
# The magnitude of the difference between 'semiconductor' and 'earthworm' is 5.67
# The magnitude of the difference between 'hi' and 'hello' is 2.64
